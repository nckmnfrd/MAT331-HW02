# %% [markdown]
# <h1> Homework 02 </h1>
#
# <h3> Due Tue, Feb 12, 11:59pm </h3>
#
# Download the .ipynb file for this notebook, and place your solutions where indicated (you can use multiple cells for each problem).  Name the file hw02.ipynb (you do not need to include your netid in the title). Then upload it to Blackboard as Homework 2 in the Assignments tab. See Collaboration Policy in Homework section of course webpage (it's the same as it was for HW01).  Please include comments in your code to make it easier to read.

# %% [markdown]
# <h2> Problem 1 </h2>
#
# Write a function that takes as input an integer $n$ and returns its factorization into prime numbers.  The output should be a list of the prime factors, with each prime $p$ appearing $k$ times in the list where $k$ is the largest power of $p$ such that $p^k$ divides $n$.  The order of the elements of the list does not matter.  For instance, if $n=12$, any of [2,2,3], [2,3,2], or [3,2,2] would be vaild outputs. Do not use the built-in factor function.  Test your function on $2^{22}-1, 2^{23}-1$, and $2^{24}-1$.

# %%
# Put your solution here (you can add more cells using the Insert menu)
def prime(n):  ##defining the function prime
    i = 2  ##start checking with the first prime number known
    factors = [] ##creating a list to store prime numbers that are recieved 
    while i * i <= n:          ##the remaining code is just prime factorization
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
            factors.append(n)
    return factors

# %%
prime(2^22-1)
# Out:
# [3, 23, 89, 683]

# %%
prime(2^23-1)
# Out:
# [47, 178481]

# %%
prime(2^24-1)
# Out:
# [3, 3, 5, 7, 13, 17, 241]

# %% [markdown]
# <h2> Problem 2 </h2>
#
# (a) Write a function that takes as input a string of characters, and returns the characters in reverse order (either as a list of characters, or as a string).  Try your function on "MADWARWOLF".  It should return "FLOWRAWDAM" (or a list of these characters).
#
# (b) Write a function that takes as input a string of characters, and applies the above reverse cipher, followed by a shift (Caesar) cipher like the one we did in class (shifting by an amount of your choice).  How hard would it be to break this combination cipher?

# %%
def reverse(n):
    str = ""
    for i in n:
        str = i + str
    return str

reverse("MADWARWOLF")
# Out:
# 'FLOWRAWDAM'

# %%
character = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

def caesar_shift(plaintext, shift):
    cipher = reverse(plaintext) 
    str = ""
    for i in cipher:
        str =str + character[(character.index(i) + shift) % 26]
    
    return str 

caesar_shift("ABCDEFGHIJKLMNOPQRSTUVWXYZ", 3)
        
    ##it would be very easy to break this combination cipher, it has a finite amount of shifts(26) and checking each shift 
    ##would eventually give the plaintext
# Out:
# 'CBAZYXWVUTSRQPONMLKJIHGFED'

# %% [markdown]
# <h2> Problem 3 </h2>
#
# I made a string of capital letters by starting with some lyrics of a song written in English and stripping out all spaces and punctuation.  I then encrypted this string with the shift (Caesar) cipher, obtaining the string below.  What string did I start with, and what key did I use?
#
# EVMVIKYFLXYKZUSVFERSFRKZKJRSZXSCLVNRKVIPIFRUGFJVZUFECFFBRKDVEVMVIKYFLXYKZUJVVKYVURPNYVERSZXSFRKTFDZEXDPNRP

# %%
character = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

def caesar_deshift(plaintext, shift):
    
    cipher = plaintext
    str = ""
    for i in cipher:
        str =str + character[(character.index(i) - shift) % 26]
    
    return str 

for i in range(1,26):
    print caesar_deshift("EVMVIKYFLXYKZUSVFERSFRKZKJRSZXSCLVNRKVIPIFRUGFJVZUFECFFBRKDVEVMVIKYFLXYKZUJVVKYVURPNYVERSZXSFRKTFDZEXDPNRP",i)
##the string that was orignially used to start was NEVERTHOUGHTIDBEONABOATITSABIGBLUEWATERYROADPOSEIDONLOOKATMENEVERTHOUGHTIDSEETHEDAYWHENABIGBOATCOMINGMYWAY
##the key that was used was shifted 17 places
##im on a motherfucking boat
# Out:
# DULUHJXEKWXJYTRUEDQREQJYJIQRYWRBKUMQJUHOHEQTFEIUYTEDBEEAQJCUDULUHJXEKWXJYTIUUJXUTQOMXUDQRYWREQJSECYDWCOMQO
# CTKTGIWDJVWIXSQTDCPQDPIXIHPQXVQAJTLPITGNGDPSEDHTXSDCADDZPIBTCTKTGIWDJVWIXSHTTIWTSPNLWTCPQXVQDPIRDBXCVBNLPN
# BSJSFHVCIUVHWRPSCBOPCOHWHGOPWUPZISKOHSFMFCORDCGSWRCBZCCYOHASBSJSFHVCIUVHWRGSSHVSROMKVSBOPWUPCOHQCAWBUAMKOM
# ARIREGUBHTUGVQORBANOBNGVGFNOVTOYHRJNGRELEBNQCBFRVQBAYBBXNGZRARIREGUBHTUGVQFRRGURQNLJURANOVTOBNGPBZVATZLJNL
# ZQHQDFTAGSTFUPNQAZMNAMFUFEMNUSNXGQIMFQDKDAMPBAEQUPAZXAAWMFYQZQHQDFTAGSTFUPEQQFTQPMKITQZMNUSNAMFOAYUZSYKIMK
# YPGPCESZFRSETOMPZYLMZLETEDLMTRMWFPHLEPCJCZLOAZDPTOZYWZZVLEXPYPGPCESZFRSETODPPESPOLJHSPYLMTRMZLENZXTYRXJHLJ
# XOFOBDRYEQRDSNLOYXKLYKDSDCKLSQLVEOGKDOBIBYKNZYCOSNYXVYYUKDWOXOFOBDRYEQRDSNCOODRONKIGROXKLSQLYKDMYWSXQWIGKI
# WNENACQXDPQCRMKNXWJKXJCRCBJKRPKUDNFJCNAHAXJMYXBNRMXWUXXTJCVNWNENACQXDPQCRMBNNCQNMJHFQNWJKRPKXJCLXVRWPVHFJH
# VMDMZBPWCOPBQLJMWVIJWIBQBAIJQOJTCMEIBMZGZWILXWAMQLWVTWWSIBUMVMDMZBPWCOPBQLAMMBPMLIGEPMVIJQOJWIBKWUQVOUGEIG
# ...

# %% [markdown]
# <h2> Problem 4 </h2>
#
# Find several paragraphs of text written in English (eg from a book, magazine, news article, email exchange, etc). Strip out all non-letter characters (spaces, punctuation, numbers, etc), and convert all remaining letters to upper-case. Call this string CORPUS1. Ideally it should have at least 1000 characters.  Determine the relative frequency of each letter in CORPUS1.  Your output should be a list of the frequencies of each of the 26 letters.

# %%
CORPUS1 = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc vehicula massa fringilla leo ultricies, eget ullamcorper eros lobortis. Integer vel congue turpis. Curabitur eget gravida ligula. Donec eleifend odio ut velit malesuada, nec molestie orci auctor. Pellentesque felis dui, condimentum ut fringilla at, ultrices et mi. Integer semper augue non sollicitudin pretium. Maecenas laoreet ligula sit amet purus viverra interdum. Phasellus gravida neque enim, non ultricies neque lacinia eu. Quisque viverra lorem justo, vel luctus lorem tincidunt nec. Vivamus ac neque vitae nunc pulvinar vestibulum eget commodo enim. Etiam eu est a massa commodo ornare et ac augue. Integer fermentum enim non felis dictum, in vestibulum nisi euismod. Quisque scelerisque, dolor eu finibus elementum, risus metus feugiat lectus, ut volutpat massa nunc ut leo.Nulla rhoncus suscipit elementum. Nulla tempor dui urna. Pellentesque feugiat nisi gravida lacinia tincidunt. Interdum et malesuada fames ac ante ipsum primis in faucibus. Sed lorem leo, dignissim vitae consectetur vehicula, pulvinar et massa. Duis congue velit vel consequat aliquet. Nam in arcu consectetur, iaculis nunc et, feugiat lectus. Vivamus at libero quam. Curabitur dignissim tellus sit amet massa maximus egestas. Suspendisse potenti. Curabitur ornare non felis eget mattis. Fusce sed lorem faucibus, elementum libero dignissim, tristique odio"
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
str = ""
freq = [0] * 26
for i in CORPUS1:
    if i in alphabet:
        str = str + i.upper()
        freq[alphabet.index(i.upper())] += 1 
        
CORPUS1 = str
print CORPUS1
print freq
# Out:
# ...
# [84, 11, 52, 31, 147, 15, 26, 4, 120, 1, 0, 72, 61, 77, 53, 19, 14, 61, 88, 89, 108, 25, 0, 1, 0, 0]

# %% [markdown]
# <h2> Problem 5 </h2>
#
# (a) Convert CORPUS1 from above into a list of integers between 0 and 25 by taking each character to its place in the alphabet, starting with 0.  For example "ZAP" would go to [25,0,15].
#
# (b) Starting with a different collection of paragraphs from a similar source, generate a new CORPUS2 in a similar way.  Convert CORPUS2 into a list of integers, as you did for CORPUS1.
#
# (c) Truncate the longer of the two lists you created above so that they become the same length.  Now subtract the first list from the second element-wise modulo 26.  For instance if the two lists were [25,0,15] and [2,0,1], the new list would be [3,0,12]. What are the relative frequencies of each of the numbers 0,...,25 in this list?

# %%
##print CORPUS1
list = []
for i in CORPUS1:
    list.append(alphabet.index(i))
    
print list
CORPUS1 = list
# Out:
# [11, 14, 17, 4, 12, 8, 15, 18, 20, 12, 3, 14, 11, 14, 17, 18, 8, 19, 0, 12, 4, 19, 2, 14, 13, 18, 4, 2, 19, 4, 19, 20, 17, 0, 3, 8, 15, 8, 18, 2, 8, 13, 6, 4, 11, 8, 19, 13, 20, 13, 2, 21, 4, 7, 8, 2, 20, 11, 0, 12, 0, 18, 18, 0, 5, 17, 8, 13, 6, 8, 11, 11, 0, 11, 4, 14, 20, 11, 19, 17, 8, 2, 8, 4, 18, 4, 6, 4, 19, 20, 11, 11, 0, 12, 2, 14, 17, 15, 4, 17, 4, 17, 14, 18, 11, 14, 1, 14, 17, 19, 8, 18, 8, 13, 19, 4, 6, 4, 17, 21, 4, 11, 2, 14, 13, 6, 20, 4, 19, 20, 17, 15, 8, 18, 2, 20, 17, 0, 1, 8, 19, 20, 17, 4, 6, 4, 19, 6, 17, 0, 21, 8, 3, 0, 11, 8, 6, 20, 11, 0, 3, 14, 13, 4, 2, 4, 11, 4, 8, 5, 4, 13, 3, 14, 3, 8, 14, 20, 19, 21, 4, 11, 8, 19, 12, 0, 11, 4, 18, 20, 0, 3, 0, 13, 4, 2, 12, 14, 11, 4, 18, 19, 8, 4, 14, 17, 2, 8, 0, 20, 2, 19, 14, 17, 15, 4, 11, 11, 4, 13, 19, 4, 18, 16, 20, 4, 5, 4, 11, 8, 18, 3, 20, 8, 2, 14, 13, 3, 8, 12, 4, 13, 19, 20, 12, 20, 19, 5, 17, 8, 13, 6, 8, 11, 11, 0, 0, 19, 20, 11, 19, 17, 8, 2, 4, 18, 4, 19, 12, 8, 8, 13, 19, 4, 6, 4, 17, 18, 4, 12, 15,
# ...

# %%
CORPUS2 = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Morbi eu bibendum sapien. Donec libero magna, ultrices eu purus quis, porttitor placerat eros. Ut id mauris gravida magna elementum ullamcorper quis vel mi. Morbi eu varius odio. Donec varius, neque feugiat molestie varius, enim ex sollicitudin massa, non convallis dui tortor ac metus. Proin hendrerit semper turpis. Proin faucibus felis eu venenatis suscipit. Curabitur porta, eros non porttitor tincidunt, lectus mauris varius dui, at tempor metus metus in urna. Proin ut mattis nulla, hendrerit consectetur risus. Sed ut laoreet nisi, at blandit est. Suspendisse gravida feugiat fringilla. In porttitor tempor enim quis egestas.Praesent congue varius quam vitae egestas. Orci varius natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Etiam maximus massa nec sem tincidunt dictum. Cras et enim sagittis, accumsan sapien id, sodales eros. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Curabitur mattis pellentesque imperdiet. Integer auctor sapien eu velit scelerisque, tincidunt lobortis ex elementum. Cras faucibus lectus vitae feugiat rhoncus. Ut vel odio vehicula lorem aliquet suscipit non at ligula.aximus ornare vel justo. Nunc laoreet varius odio at luctus. Praesent vitae turpis sit amet lorem tempus interdum ut eu ligula. Vestibulum vitae lectus nec augue interdum congue. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos."
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
str = ""
freq = [0] * 26
for i in CORPUS2:
    if i in alphabet:
        str = str + i.upper()
        freq[alphabet.index(i.upper())] += 1 
CORPUS2 = str

list = []
for i in CORPUS2:
    list.append(alphabet.index(i))
    
print list
CORPUS2 = list
# Out:
# [11, 14, 17, 4, 12, 8, 15, 18, 20, 12, 3, 14, 11, 14, 17, 18, 8, 19, 0, 12, 4, 19, 2, 14, 13, 18, 4, 2, 19, 4, 19, 20, 17, 0, 3, 8, 15, 8, 18, 2, 8, 13, 6, 4, 11, 8, 19, 12, 14, 17, 1, 8, 4, 20, 1, 8, 1, 4, 13, 3, 20, 12, 18, 0, 15, 8, 4, 13, 3, 14, 13, 4, 2, 11, 8, 1, 4, 17, 14, 12, 0, 6, 13, 0, 20, 11, 19, 17, 8, 2, 4, 18, 4, 20, 15, 20, 17, 20, 18, 16, 20, 8, 18, 15, 14, 17, 19, 19, 8, 19, 14, 17, 15, 11, 0, 2, 4, 17, 0, 19, 4, 17, 14, 18, 20, 19, 8, 3, 12, 0, 20, 17, 8, 18, 6, 17, 0, 21, 8, 3, 0, 12, 0, 6, 13, 0, 4, 11, 4, 12, 4, 13, 19, 20, 12, 20, 11, 11, 0, 12, 2, 14, 17, 15, 4, 17, 16, 20, 8, 18, 21, 4, 11, 12, 8, 12, 14, 17, 1, 8, 4, 20, 21, 0, 17, 8, 20, 18, 14, 3, 8, 14, 3, 14, 13, 4, 2, 21, 0, 17, 8, 20, 18, 13, 4, 16, 20, 4, 5, 4, 20, 6, 8, 0, 19, 12, 14, 11, 4, 18, 19, 8, 4, 21, 0, 17, 8, 20, 18, 4, 13, 8, 12, 4, 23, 18, 14, 11, 11, 8, 2, 8, 19, 20, 3, 8, 13, 12, 0, 18, 18, 0, 13, 14, 13, 2, 14, 13, 21, 0, 11, 11, 8, 18, 3, 20, 8, 19, 14, 17, 19, 14, 17, 0, 2, 12, 4, 19
# ...

# %%
print len (CORPUS1)
print len (CORPUS2)
list = []
if len(CORPUS2) > len(CORPUS1):
        CORPUS2 = CORPUS2[:len(CORPUS1)]
else:
        CORPUS1 = CORPUS1[:len(CORPUS2)]
for i in range(len(CORPUS2)):
    list.append((CORPUS2[i] - CORPUS1[i]) % 26)
       
print list
# Out:
# 1159
# 1159
# ...

# %% [markdown]
# <h2> Problem 6 </h2>
#
# (a) Take two English messages consisting of capital letters with no spaces or punctuation, each the same length of about a paragraph.  Encrypt both messages using a one-time pad, using a different randomly chosen key for each.  Now convert each encrypted message into a list of integers, exactly as in parts (a) and (b) of the previous problem. Subtract one list from the other element-wise modulo 26, as in the previous problem.  What are the relative frequencies of each of the numbers 0,...,25 in the resulting list?
#
# (b) Repeat part (a) above with the same two messages, but this time encrypt them with the same key (randomly chosen, and different from the two used previously).  Do the same subtraction process as in (a).  What are the relative frequences of each of the numbers 0,...,25 in the resulting list?
#
# (c) Do parts (a), (b), together with the results from Problem 5,  suggest a way to test whether the key for a one-time pad has been re-used based only on a collection of encrypted messages?

# %%
from random import randint
MESSAGE1 = "Pellentesque sollicitudin lorem id venenatis pretium. Vivamus tempus arcu id dolor convallis, consectetur placerat sem efficitur. Nullam nec ligula eu turpis hendrerit varius non venenatis purus. Sed iaculis ipsum tristique cursus mattis. Etiam laoreet at tellus a imperdiet. Vestibulum condimentum orci est, eu cursus sapien ultricies eget. In tempus vulputate nisi, eu mattis magna sodales nec. Ut a lectus tempor, pharetra enim a, vehicula justo. Integer porta ante quis feugiat egestas. Nunc imperdiet varius augue at tincidunt."
MESSAGE2 = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Cras faucibus sollicitudin tortor id volutpat. Etiam posuere quam quis felis convallis, a tincidunt nisl euismod. Nunc ornare, magna ac fermentum tristique, sapien enim sagittis metus, sit amet malesuada neque dui ut felis. Aenean sodales pharetra justo, vel egestas mi porta sit amet. Pellentesque tempus molestie tincidunt. Donec sed velit mollis, feugiat orci id, varius tellus. Lorem ipsum dolor sit amet, consectetur adipiscing elit. In et ligula in enim condimentum sollicitudin. Nullam lobortis consectetur erat, quis placerat sem porttitor mattis. Ut non condimentum mauris. Ut tempor tincidunt justo id venenatis. Integer venenatis augue sit amet ipsum varius, a feugiat dolor porta. Sed diam velit, tempus nec nulla ut, porttitor feugiat urna."
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

oneTimePad = []
for i in range(0,100000):
    oneTimePad.append(randint(0,25))

oneTimePad2 = []
for i in range(0,100000):
    oneTimePad2.append(randint(0,25))

str = ""
freqM1 = [0] * 26
for i in MESSAGE1:
    if i in alphabet:
        str = str + i.upper()
        freqM1[alphabet.index(i.upper())] += 1 
MESSAGE1 = str

list = []
for i in MESSAGE1:
    list.append(alphabet.index(i))

str2 = ""
freqM2 = [0] * 26
for i in MESSAGE2:
    if i in alphabet:
        str2 = str + i.upper()
        freqM2[alphabet.index(i.upper())] += 1 
MESSAGE2 = str

list2 = []
for i in MESSAGE2:
    list.append(alphabet.index(i))
    print i

encodedMessage1 = []
i = 0
for asciiVal in list:
    encodedMessage1.append((asciiVal + oneTimePad[i % 26]))
    i += 1


encodedMessage2 = []
i = 0
for asciiVal in list2:
    encodedMessage2.append((asciiVal + oneTimePad[i % 26]))
    i += 1

encodedMessage2OtherPad = []
i = 0
for asciiVal in list2:
    encodedMessage2.append((asciiVal + oneTimePad2[i % 26]))
    i += 1

freqEncodedMessage1 = [0] * 26
for i in encodedMessage1:
    freqEncodedMessage1[i] += 1 

freqEncodedMessage2 = [0] * 26
for i in encodedMessage2:
    freqEncodedMessage2[i] += 1 

freqEncodedMessage2OtherPad = [0] * 26
for i in encodedMessage2OtherPad:
    freqEncodedMessage2OtherPad[i] += 1 


print "Message 1 frequency" + freqM1
print "Message 2 frequency" + freqM2
print "Message 1 encoded frequency" + freqEncodedMessage1
print "Message 2 encoded frequency using same pad as message 1" + freqEncodedMessage2
print "Message 2 encoded frequency using different pad as message 1" + freqEncodedMessage2OtherPad
# Out:
# P
# E
# L
# L
# E
# N
# T
# E
# S
# Q
# U
# E
# S
# O
# L
# L
# I
# C
# I
# T
# U
# D
# I
# N
# L
# O
# R
# E
# M
# I
# D
# V
# E
# N
# E
# N
# A
# T
# I
# S
# P
# R
# E
# T
# I
# U
# M
# V
# I
# V
# A
# M
# U
# S
# T
# E
# M
# P
# U
# S
# A
# R
# C
# U
# I
# D
# D
# O
# L
# O
# R
# C
# O
# N
# V
# A
# L
# L
# I
# S
# C
# O
# N
# S
# E
# C
# T
# E
# T
# U
# R
# P
# L
# A
# C
# E
# R
# A
# T
# S
# E
# M
# E
# F
# F
# I
# C
# I
# T
# U
# R
# N
# U
# L
# L
# A
# M
# N
# E
# C
# L
# I
# G
# U
# L
# A
# E
# U
# T
# U
# R
# P
# I
# S
# H
# E
# N
# D
# R
# E
# R
# I
# T
# V
# A
# R
# I
# U
# S
# N
# O
# N
# V
# E
# N
# E
# N
# A
# T
# I
# S
# P
# U
# R
# U
# S
# S
# E
# D
# I
# A
# C
# U
# L
# I
# S
# I
# P
# S
# U
# M
# T
# R
# I
# S
# T
# I
# Q
# U
# E
# C
# U
# R
# S
# U
# S
# M
# A
# T
# T
# I
# S
# E
# T
# I
# A
# M
# L
# A
# O
# R
# E
# E
# T
# A
# T
# T
# E
# L
# L
# U
# S
# A
# I
# M
# P
# E
# R
# D
# I
# E
# T
# V
# E
# S
# T
# I
# B
# U
# L
# U
# M
# C
# O
# N
# D
# I
# M
# E
# N
# ...
